# %% [markdown]
# <a href="https://colab.research.google.com/github/Titas23/IS-170-Machine-Learning/blob/10.-Support-Vector-Machines/SVM_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# David Bautista/ Andres Perez

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
mydata=pd.read_csv("data2.csv")
mydata
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
mydata.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
#the x data is saved without 'target' column to make only features dataframe
x=mydata.drop('Bankrupt?',axis=1)

x
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# 6817                                           0.506264
# 6818                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...

# %%
#the y data is saved only with 'target' column
y=mydata['Bankrupt?']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6814    0
# 6815    0
# 6816    0
# 6817    0
# 6818    0
# Name: Bankrupt?, Length: 6819, dtype: int64

# %%
#create a model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=2)

# %%
#kernel specifying
clf=svm.SVC(kernel='rbf')

#train and fit the model
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
#predict the response
y_pred=clf.predict(x_test)

# %%
#model accuracy
print("Accuracy: ", metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.9728739002932552

# %%
#model precision
print("Precision: ",metrics.precision_score(y_test,y_pred, average='macro'))

#model recall
print("Recall: ", metrics.recall_score(y_test,y_pred, average='macro'))
# Out:
# Precision:  0.4864369501466276
# Recall:  0.5
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
